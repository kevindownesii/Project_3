# %%
import censusdis.data as ced

# %%
#American Community Survey 5 year data
DATASET = "acs/acs5"

# %%
#Year for data
YEAR = 2020

# %%
#Population & Median Household income variables
TOTAL_POPULATION_VARIABLE = "B01003_001E"
MEDIAN_HOUSEHOLD_INCOME_VARIABLE = "B19013_001E"

# %%
#Variables for query
VARIABLES = ["NAME", TOTAL_POPULATION_VARIABLE, MEDIAN_HOUSEHOLD_INCOME_VARIABLE]

# %%
#NJ Counties by Income
from censusdis import states

df_counties = ced.download(
    DATASET,
    YEAR,
    VARIABLES,
    state=states.NJ,
    county="*",
)

# %%
print(df_counties)
# Out:
#    STATE COUNTY                           NAME  B01003_001E  B19013_001E
# 0     34    003      Bergen County, New Jersey       931275       104623
# 1     34    009    Cape May County, New Jersey        92701        72385
# 2     34    015  Gloucester County, New Jersey       291745        89056
# 3     34    021      Mercer County, New Jersey       368085        83306
# 4     34    027      Morris County, New Jersey       492715       117298
# 5     34    033       Salem County, New Jersey        62754        64234
# 6     34    039       Union County, New Jersey       555208        82644
# 7     34    001    Atlantic County, New Jersey       264650        63680
# 8     34    005  Burlington County, New Jersey       446301        90329
# 9     34    007      Camden County, New Jersey       506721        70957
# 10    34    011  Cumberland County, New Jersey       150085        55709
# 11    34    013       Essex County, New Jersey       798698        63959
# ...

# %%
df_counties.columns = ['STATE_CODE', 'COUNTY_CODE', 'COUNTY_NAME', 'POPULATION', 'MEDIAN_INCOME']

# %%
df_counties
# Out:
#    STATE_CODE COUNTY_CODE                    COUNTY_NAME  POPULATION  \
# 0          34         003      Bergen County, New Jersey      931275
# 1          34         009    Cape May County, New Jersey       92701
# 2          34         015  Gloucester County, New Jersey      291745
# 3          34         021      Mercer County, New Jersey      368085
# 4          34         027      Morris County, New Jersey      492715
# 5          34         033       Salem County, New Jersey       62754
# 6          34         039       Union County, New Jersey      555208
# 7          34         001    Atlantic County, New Jersey      264650
# 8          34         005  Burlington County, New Jersey      446301
# 9          34         007      Camden County, New Jersey      506721
# 10         34         011  Cumberland County, New Jersey      150085
# 11         34         013       Essex County, New Jersey      798698
# 12         34         017      Hudson County, New Jersey      671923
# ...

# %%
df_sorted = df_counties.sort_values(by='POPULATION', ascending=False)
df_sorted
# Out:
#    STATE_CODE COUNTY_CODE                    COUNTY_NAME  POPULATION  \
# 0          34         003      Bergen County, New Jersey      931275
# 14         34         023   Middlesex County, New Jersey      825015
# 11         34         013       Essex County, New Jersey      798698
# 12         34         017      Hudson County, New Jersey      671923
# 15         34         025    Monmouth County, New Jersey      620821
# 16         34         029       Ocean County, New Jersey      602018
# 6          34         039       Union County, New Jersey      555208
# 9          34         007      Camden County, New Jersey      506721
# 17         34         031     Passaic County, New Jersey      502763
# 4          34         027      Morris County, New Jersey      492715
# 8          34         005  Burlington County, New Jersey      446301
# 3          34         021      Mercer County, New Jersey      368085
# 18         34         035    Somerset County, New Jersey      330151
# ...

# %%
# write dataframe to csv
# df_counties.to_csv('output.csv', index=False)
# df_sorted.to_csv('output.csv', index=False)

# %%
gdf_counties = ced.download(
    DATASET,
    YEAR,
    VARIABLES,
    state=states.NJ,
    county="*",
    with_geometry=True
)

# %%
import censusdis.maps as cem

ax = cem.plot_us(
    gdf_counties,
    MEDIAN_HOUSEHOLD_INCOME_VARIABLE,
    cmap="viridis",
    legend=True,
    vmin=0.0,
    vmax=150_000,
    figsize=(12, 6)
)

ax.set_title(f"{YEAR} Median Household Income by County")

ax.axis("off")
# Out:
# (2048295.928045771, 2183092.8315101922, -362350.1953134922, -67931.86509457673)

# %%
#Education stats
total_population = "B15003_001E"
high_school_grad = "B15003_017E"
bachelor = "B15003_022E"
professional = "B15003_024E"

# %%
#Variables for query
VARIABLES = ["NAME", total_population, high_school_grad, bachelor, professional]

# %%
#NJ Counties by Income
from censusdis import states

df_edu_counties = ced.download(
    DATASET,
    YEAR,
    VARIABLES,
    state=states.NJ,
    county="*",
)

# %%
df_edu_counties
# Out:
#    STATE COUNTY                           NAME  B15003_001E  B15003_017E  \
# 0     34    003      Bergen County, New Jersey       658233       133493
# 1     34    009    Cape May County, New Jersey        69871        20176
# 2     34    015  Gloucester County, New Jersey       202353        57091
# 3     34    021      Mercer County, New Jersey       248245        57185
# 4     34    027      Morris County, New Jersey       346577        61342
# 5     34    033       Salem County, New Jersey        44054        15409
# 6     34    039       Union County, New Jersey       378158        99258
# 7     34    001    Atlantic County, New Jersey       184504        53404
# 8     34    005  Burlington County, New Jersey       316051        78222
# 9     34    007      Camden County, New Jersey       349563        90822
# 10    34    011  Cumberland County, New Jersey       101692        32446
# 11    34    013       Essex County, New Jersey       538203       135061
# ...

# %%
df_edu_counties.columns = ['STATE_CODE', 'COUNTY_CODE', 'COUNTY_NAME', 'POPULATION_25+', 'HIGH_SCHOOL', 'BACHELOR', 'PROFESSIONAL']

# %%
df_edu_counties
# Out:
#    STATE_CODE COUNTY_CODE                    COUNTY_NAME  POPULATION_25+  \
# 0          34         003      Bergen County, New Jersey          658233
# 1          34         009    Cape May County, New Jersey           69871
# 2          34         015  Gloucester County, New Jersey          202353
# 3          34         021      Mercer County, New Jersey          248245
# 4          34         027      Morris County, New Jersey          346577
# 5          34         033       Salem County, New Jersey           44054
# 6          34         039       Union County, New Jersey          378158
# 7          34         001    Atlantic County, New Jersey          184504
# 8          34         005  Burlington County, New Jersey          316051
# 9          34         007      Camden County, New Jersey          349563
# 10         34         011  Cumberland County, New Jersey          101692
# 11         34         013       Essex County, New Jersey          538203
# ...

# %%
edu_counties = ced.download(
    DATASET,
    YEAR,
    VARIABLES,
    state=states.NJ,
    county="*",
    with_geometry=True
)

# %%
import censusdis.maps as cem

ax = cem.plot_us(
    edu_counties,
    bachelor,
    cmap="viridis",
    legend=True,
    vmin=5000,
    vmax=215000,
    figsize=(12, 6)
)

ax.set_title(f"{YEAR} Bachelor level by County")

ax.axis("off")
# Out:
# (2048295.928045771, 2183092.8315101922, -362350.1953134922, -67931.86509457673)

# %%
import pandas as pd

# Calculate percentages for each education level

df_edu_counties['HIGH_SCHOOL_PERCENTAGE'] = (df_edu_counties['HIGH_SCHOOL'] / df_edu_counties['POPULATION_25+']) * 100
df_edu_counties['BACHELOR_PERCENTAGE'] = (df_edu_counties['BACHELOR'] / df_edu_counties['POPULATION_25+']) * 100
df_edu_counties['PROFESSIONAL_PERCENTAGE'] = (df_edu_counties['PROFESSIONAL'] / df_edu_counties['POPULATION_25+']) * 100

# Display the updated dataframe
df_edu_counties
# Out:
#    STATE_CODE COUNTY_CODE                    COUNTY_NAME  POPULATION_25+  \
# 0          34         003      Bergen County, New Jersey          658233
# 1          34         009    Cape May County, New Jersey           69871
# 2          34         015  Gloucester County, New Jersey          202353
# 3          34         021      Mercer County, New Jersey          248245
# 4          34         027      Morris County, New Jersey          346577
# 5          34         033       Salem County, New Jersey           44054
# 6          34         039       Union County, New Jersey          378158
# 7          34         001    Atlantic County, New Jersey          184504
# 8          34         005  Burlington County, New Jersey          316051
# 9          34         007      Camden County, New Jersey          349563
# 10         34         011  Cumberland County, New Jersey          101692
# 11         34         013       Essex County, New Jersey          538203
# ...

# %%
import censusdis.maps as cem

ax = cem.plot_us(
    edu_counties,
    df_edu_counties['BACHELOR_PERCENTAGE'],
    cmap="viridis",
    legend=True,
    vmin=0,
    vmax=35,
    figsize=(12, 6)
)

ax.set_title(f"{YEAR} Bachelor % by County")

ax.axis("off")
# Out:
# (2048295.928045771, 2183092.8315101922, -362350.1953134922, -67931.86509457673)
